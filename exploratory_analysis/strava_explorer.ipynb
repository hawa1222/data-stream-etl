# %%
import pandas as pd

from utility import data_standardiser

# %%
### Load Strava Data

data_path = "/Users/hadid/GitHub/ETL/data/raw_data/strava_data.xlsx"
strava_data = pd.read_excel(data_path)
strava_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1247 entries, 0 to 1246
# Data columns (total 94 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   resource_state                                   1247 non-null   int64
#  1   name                                             1247 non-null   object
#  2   distance                                         1247 non-null   float64
#  3   moving_time                                      1247 non-null   int64
#  4   elapsed_time                                     1247 non-null   int64
#  5   total_elevation_gain                             1247 non-null   float64
#  6   type                                             1247 non-null   object
#  7   sport_type                                       1247 non-null   object
#  8   workout_type                                     120 non-null    float64
# ...

# %%
# Standardise data
new_activity_data_df = data_standardiser.CleanData.clean_data(
    strava_data, na_threshold=20
)
new_activity_data_df.info()
# Out:
# [2024-07-03 15:18:46] [INFO]  Standardising data...
# [2024-07-03 15:18:46] [INFO]  Dropped 0 rows with more than 20 NaN values
# [2024-07-03 15:18:46] [INFO]  Standardised column names
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1247 entries, 0 to 1246
# Data columns (total 94 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   resource_state                                   1247 non-null   int64
#  1   name                                             1247 non-null   object
#  2   distance                                         1247 non-null   float64
#  3   moving_time                                      1247 non-null   int64
#  4   elapsed_time                                     1247 non-null   int64
#  5   total_elevation_gain                             1247 non-null   float64
# ...

# %%
# Find mismatched fields
new_fields = new_activity_data_df.columns
old_fields = strava_data.columns

for i in range(len(new_fields)):
    if new_fields[i] != old_fields[i]:
        print(f"Mismatch found at index {i}: {new_fields[i]} != {old_fields[i]}")
